# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Boston1.csv')

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.shape
# Out:
# (506, 14)

# %%
sns.distplot(df['medv'])
plt.show()
# Out:
# C:\Users\Saurabh\AppData\Local\Temp\ipykernel_820\3132154289.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['medv'])

# %%
corr_matrix=df.corr().round(2)

# %%
corr_matrix
# Out:
#          crim    zn  indus  chas   nox    rm   age   dis   rad   tax  ptratio  \
# crim     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# zn      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# indus    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# chas    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# nox      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# rm      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# age      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# dis     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# rad      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# tax      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# ptratio  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# black   -0.39  0.18  -0.36  0.05 -0.38  0.13 -0.27  0.29 -0.44 -0.44    -0.18
# lstat    0.46 -0.41   0.60 -0.05  0.59 -0.61  0.60 -0.50  0.49  0.54     0.37
# medv    -0.39  0.36  -0.48  0.18 -0.43  0.70 -0.38  0.25 -0.38 -0.47    -0.51
#
#          black  lstat  medv
# crim     -0.39   0.46 -0.39
# zn        0.18  -0.41  0.36
# indus    -0.36   0.60 -0.48
# chas      0.05  -0.05  0.18
# nox      -0.38   0.59 -0.43
# rm        0.13  -0.61  0.70
# age      -0.27   0.60 -0.38
# dis       0.29  -0.50  0.25
# rad      -0.44   0.49 -0.38
# tax      -0.44   0.54 -0.47
# ptratio  -0.18   0.37 -0.51
# black     1.00  -0.37  0.33
# lstat    -0.37   1.00 -0.74
# medv      0.33  -0.74  1.00

# %%
plt.figure(figsize=(9,7))
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
#model building

# %%
x=df[['lstat','rm']]
y=df['medv']

# %%
x.shape
# Out:
# (506, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=6)

# %%
print(x_test.shape)
print(x_train.shape)
# Out:
# (102, 2)
# (404, 2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics  import r2_score,mean_squared_error

# %%
model= LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_pred=model.predict(x_test)

# %%
test_pred
# Out:
# array([27.2099036 , 27.8551659 , 27.55270675, 26.06358329, 22.08725894,
#        23.74622652, 18.78034062, 39.22668655, 25.35593559, 18.92128561,
#        28.74157443, 16.80330772, 38.49715618, 31.78450785, 33.48995374,
#        17.87615194, 14.68236701, 28.21357413, 18.92313259, 10.93120245,
#        10.64753604, 29.65343577, 24.25563727, 21.95948089, 20.42570662,
#        19.45767135, 18.53790368, 26.66680562, 19.77547471, 20.05068294,
#        22.71142631, 21.84074667, 27.33385396, 36.72854378, 22.98846094,
#        22.40116627, 19.87995336, 23.00317173, 17.43889827,  1.83879799,
#        13.04072216, 13.11368974,  9.36333679, 12.49585325, 21.96368665,
#        26.84840213, 31.06303261, 21.75584959, 20.35691761, 18.50204136,
#        22.73991908, 18.28898596, 20.9158661 , 20.38285063, 33.63247309,
#        31.94146207, 16.81898444, 29.5228731 , 19.44634809, 23.50850604,
#        23.881247  , 22.73609469, 11.74869704, 26.88819098, 20.56576615,
#        15.41822936, 32.88437594, 15.14496914, 24.01436943, 31.86578482,
#        10.9432102 , 22.81506505, 14.99677733, 20.13606242, 32.761361  ,
#        23.50156453, 20.58514123, 36.27305584, 14.40992172, 22.95307442,
#        18.80905825, 15.29559249, -4.94587919, 29.14265936, 19.76230557,
#        28.72260681, 10.12748983, 20.00785413, 17.28926694, 38.13733011,
#        11.56307076,  1.04683336, 15.04986684, 20.34346593, 23.07464542,
#        19.1341867 , 26.41669601, 20.17071008, 26.02554039, 16.22414755,
#        24.78196438, 24.12378278])

# %%
mse=mean_squared_error(y_test,test_pred)

# %%
mse
# Out:
# 32.33297880074563

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 5.686209528389332

# %%
r2_score=r2_score(y_test,test_pred)
r2_score
# Out:
# 0.6245732517986632
