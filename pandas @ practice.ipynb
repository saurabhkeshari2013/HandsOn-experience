# %%
import pandas as pd
import numpy as np

# %%
empty=pd.Series()

# %%
print(empty)
# Out:
# Series([], dtype: object)

# %%
ser=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'],dtype=float)
print(ser)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
arr=np.array([2,3,4,5,6])
ser=pd.Series(arr)
ser
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int32

# %%
arr=np.array(['a','b','c','d','e'])
ser=pd.Series(arr)
ser
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
ser=pd.Series([1,2,3,4,5], index=('a','b','c','d','e'), dtype=float)

# %%
ser
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
ser=pd.Series(np.array([2,3,4,5,6]), index=np.arange(12,17))
ser
# Out:
# 12    2
# 13    3
# 14    4
# 15    5
# 16    6
# dtype: int32

# %%
dict={'dog':100,'cat':200,'hen':300}
dict
# Out:
# {'dog': 100, 'cat': 200, 'hen': 300}

# %%
df2=pd.Series(dict)
df2
# Out:
# dog    100
# cat    200
# hen    300
# dtype: int64

# %%
df2['cow']=360
df2
# Out:
# dog    100
# cat    200
# hen    300
# cow    360
# dtype: int64

# %%
dataf=pd.DataFrame()
print(dataf)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list1=['om','jai','jagdeesh']
df1=pd.DataFrame(list1)
df1
# Out:
#           0
# 0        om
# 1       jai
# 2  jagdeesh

# %%
list2=[['om',25],['namah',15],['shivay', 10]]
list2
# Out:
# [['om', 25], ['namah', 15], ['shivay', 10]]

# %%
df2=pd.DataFrame(list2, columns=['name','age'])
df2
# Out:
#      name  age
# 0      om   25
# 1   namah   15
# 2  shivay   10

# %%
dict3={'show':['got','thor','asur'],
       'rating':[5,7,8]
      }
df=pd.DataFrame(dict3, index=("a",'b',"c"))
df
# Out:
#    show  rating
# a   got       5
# b  thor       7
# c  asur       8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   show    3 non-null      object
#  1   rating  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 72.0+ bytes

# %%
ser=pd.Series([1,2,3,4,5], index=('a','b','c','d','e'), dtype=float)
ser
df5=pd.DataFrame(ser,columns=['float'])
df5
# Out:
#    float
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0

# %%
dict={'dog':100,'cat':200,'hen':300}
df2=pd.Series(dict)
print(df2)
print()
df3=pd.DataFrame(df2,columns=['no.'])
print(df3)
print()
# Out:
# dog    100
# cat    200
# hen    300
# dtype: int64
#
#      no.
# dog  100
# cat  200
# hen  300

# %%
dict={'dog':100,'cat':200,'hen':300}
df1=pd.DataFrame(dict, index=[0])
df1
# Out:
#    dog  cat  hen
# 0  100  200  300

# %%
dict1={'emp_id': [1,2,3,6,7],
      'name': ['ram','shyam','mohan','om','som']
      }
dict2={'emp_id': [1,2,3,4,5],
      'age': [23,22,20,24,21]
      }
df1=pd.DataFrame(dict1)
df2=pd.DataFrame(dict2)

# %%
df1
# Out:
#    emp_id   name
# 0       1    ram
# 1       2  shyam
# 2       3  mohan
# 3       6     om
# 4       7    som

# %%
df2
# Out:
#    emp_id  age
# 0       1   23
# 1       2   22
# 2       3   20
# 3       4   24
# 4       5   21

# %%
m1=pd.merge(df1,df2,on='emp_id')
m1
# Out:
#    emp_id   name  age
# 0       1    ram   23
# 1       2  shyam   22
# 2       3  mohan   20

# %%
m2=pd.merge(df1,df2,on='emp_id',how='left')
m2
# Out:
#    emp_id   name   age
# 0       1    ram  23.0
# 1       2  shyam  22.0
# 2       3  mohan  20.0
# 3       6     om   NaN
# 4       7    som   NaN

# %%
m3=pd.merge(df1,df2,on='emp_id',how='outer')
m3
# Out:
#    emp_id   name   age
# 0       1    ram  23.0
# 1       2  shyam  22.0
# 2       3  mohan  20.0
# 3       6     om   NaN
# 4       7    som   NaN
# 5       4    NaN  24.0
# 6       5    NaN  21.0

# %%
dict1={'emp_id_left': [1,2,3,6,7],
      'name': ['ram','shyam','mohan','om','som']
      }
dict2={'emp_id': [1,2,3,4,5],
      'age': [23,22,20,24,21]
      }
df1=pd.DataFrame(dict1)
df2=pd.DataFrame(dict2, index=range(3,8))

# %%
dfm=pd.merge(df1,df2,left_on='emp_id_left',right_on='emp_id' ,how='left')
dfm
# Out:
#    emp_id_left   name  emp_id   age
# 0            1    ram     1.0  23.0
# 1            2  shyam     2.0  22.0
# 2            3  mohan     3.0  20.0
# 3            6     om     NaN   NaN
# 4            7    som     NaN   NaN

# %%
df2.merge(df1,left_on='emp_id',right_on='emp_id_left',how='right')
# Out:
#    emp_id   age  emp_id_left   name
# 0     1.0  23.0            1    ram
# 1     2.0  22.0            2  shyam
# 2     3.0  20.0            3  mohan
# 3     NaN   NaN            6     om
# 4     NaN   NaN            7    som

# %%
df1
# Out:
#    emp_id_left   name
# 0            1    ram
# 1            2  shyam
# 2            3  mohan
# 3            6     om
# 4            7    som

# %%
df2
# Out:
#    emp_id  age
# 3       1   23
# 4       2   22
# 5       3   20
# 6       4   24
# 7       5   21

# %%
df1.join(df2)
# Out:
#    emp_id_left   name  emp_id   age
# 0            1    ram     NaN   NaN
# 1            2  shyam     NaN   NaN
# 2            3  mohan     NaN   NaN
# 3            6     om     1.0  23.0
# 4            7    som     2.0  22.0

# %%
dict1={'emp_id': [1,2,3,6,7],
      'name': ['ram','shyam','mohani','om','som']
      }
dict2={'emp_id': [1,2,3,4,5],
      'age': [23,22,20,24,21]
      }
df1=pd.DataFrame(dict1)
df2=pd.DataFrame(dict2)

# %%
df1.join(df2, lsuffix='_l', rsuffix='_r')
# Out:
#    emp_id_l    name  emp_id_r  age
# 0         1     ram         1   23
# 1         2   shyam         2   22
# 2         3  mohani         3   20
# 3         6      om         4   24
# 4         7     som         5   21

# %%
df1
# Out:
#    emp_id    name
# 0       1     ram
# 1       2   shyam
# 2       3  mohani
# 3       6      om
# 4       7     som

# %%
df2
# Out:
#    emp_id  age
# 0       1   23
# 1       2   22
# 2       3   20
# 3       4   24
# 4       5   21

# %%
df1=df1.set_index('emp_id')
df1
# Out:
#           name
# emp_id
# 1          ram
# 2        shyam
# 3       mohani
# 6           om
# 7          som

# %%
df2=df2.set_index('emp_id')
df2
# Out:
#         age
# emp_id
# 1        23
# 2        22
# 3        20
# 4        24
# 5        21

# %%
df=df1.join(df2)
df
# Out:
#           name   age
# emp_id
# 1          ram  23.0
# 2        shyam  22.0
# 3       mohani  20.0
# 6           om   NaN
# 7          som   NaN

# %%
df2.join(df1)
# Out:
#         age    name
# emp_id
# 1        23     ram
# 2        22   shyam
# 3        20  mohani
# 4        24     NaN
# 5        21     NaN

# %%
pd.concat([df1,df2], axis=1)
# Out:
#           name   age
# emp_id
# 1          ram  23.0
# 2        shyam  22.0
# 3       mohani  20.0
# 6           om   NaN
# 7          som   NaN
# 4          NaN  24.0
# 5          NaN  21.0

# %%
dict3={'emp_id':[1,2,3],
       'gender':['m','m','f']
    
}
df3=pd.DataFrame(dict3,index=[1,2,3])
df3
# Out:
#    emp_id gender
# 1       1      m
# 2       2      m
# 3       3      f

# %%
pd.concat([df1,df3],axis=1)
# Out:
#      name  emp_id gender
# 1     ram     1.0      m
# 2   shyam     2.0      m
# 3  mohani     3.0      f
# 6      om     NaN    NaN
# 7     som     NaN    NaN

# %%
pd.concat([df1,df3])
# Out:
#      name  emp_id gender
# 1     ram     NaN    NaN
# 2   shyam     NaN    NaN
# 3  mohani     NaN    NaN
# 6      om     NaN    NaN
# 7     som     NaN    NaN
# 1     NaN     1.0      m
# 2     NaN     2.0      m
# 3     NaN     3.0      f

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Saurabh'

# %%
pd.read_csv('desktop\python class notes\datasets\mtcars2.csv')
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
pd.read_csv(r'C:\Users\Saurabh\Desktop\python class notes\datasets\mtcars2.csv')
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
m3.to_csv(r'desktop\python class notes\datasets\file1.csv',index=False)

# %%
cars_df=pd.read_csv(r'C:\Users\Saurabh\Desktop\python class notes\datasets\mtcars2.csv')
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
cars_df.head(6)
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5     6            Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2
# 5     3     1

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %%
cars_df.count()
# Out:
# S.No          32
# Unnamed: 1    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          29
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
cars_df.shape
# Out:
# (32, 13)

# %%
cars_df.std(numeric_only=True)
# Out:
# S.No      9.380832
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.780394
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
cars_df.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  29.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.780394   0.504016   0.498991   0.737804   1.6152
# ...

# %%
cars_df['cyl'].describe()
# Out:
# count    32.000000
# mean      6.187500
# std       1.785922
# min       4.000000
# 25%       4.000000
# 50%       6.000000
# 75%       8.000000
# max       8.000000
# Name: cyl, dtype: float64

# %%
#pd.set_option('display.max_columns',10)
#pd.set_option('display.max_rows',7)
#cars_df

# %%
cars_df.columns
# Out:
# Index(['S.No', 'Unnamed: 1', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')

# %%
cars_df=cars_df.rename(columns={'Unnamed: 1':'carName'})
cars_df.head(5)
# Out:
#    S.No            carName   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
cars_df.rename(columns={'disp':'display'}, inplace=True)
cars_df
# Out:
#     S.No              carName   mpg  cyl  display   hp  drat     wt   qsec  \
# 0      1            Mazda RX4  21.0    6    160.0  110  3.90  2.620  16.46
# 1      2        Mazda RX4 Wag  21.0    6    160.0  110  3.90  2.875  17.02
# 2      3           Datsun 710  22.8    4    108.0   93  3.85  2.320  18.61
# 3      4       Hornet 4 Drive  21.4    6    258.0  110  3.08  3.215  19.44
# 4      5    Hornet Sportabout  18.7    8    360.0  175  3.15  3.440  17.02
# 5      6              Valiant  18.1    6    225.0  105  2.76  3.460    NaN
# 6      7           Duster 360  14.3    8    360.0  245  3.21  3.570  15.84
# 7      8            Merc 240D  24.4    4    146.7   62  3.69  3.190  20.00
# 8      9             Merc 230  22.8    4    140.8   95  3.92  3.150  22.90
# 9     10             Merc 280  19.2    6    167.6  123  3.92  3.440  18.30
# 10    11            Merc 280C  17.8    6    167.6  123  3.92  3.440  18.90
# ...

# %%
cars_df.columns
# Out:
# Index(['S.No', 'carName', 'mpg', 'cyl', 'display', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')

# %%
cars_df.rename({1:100})
# Out:
#      S.No              carName   mpg  cyl  display   hp  drat     wt   qsec  \
# 0       1            Mazda RX4  21.0    6    160.0  110  3.90  2.620  16.46
# 100     2        Mazda RX4 Wag  21.0    6    160.0  110  3.90  2.875  17.02
# 2       3           Datsun 710  22.8    4    108.0   93  3.85  2.320  18.61
# 3       4       Hornet 4 Drive  21.4    6    258.0  110  3.08  3.215  19.44
# 4       5    Hornet Sportabout  18.7    8    360.0  175  3.15  3.440  17.02
# 5       6              Valiant  18.1    6    225.0  105  2.76  3.460    NaN
# 6       7           Duster 360  14.3    8    360.0  245  3.21  3.570  15.84
# 7       8            Merc 240D  24.4    4    146.7   62  3.69  3.190  20.00
# 8       9             Merc 230  22.8    4    140.8   95  3.92  3.150  22.90
# 9      10             Merc 280  19.2    6    167.6  123  3.92  3.440  18.30
# 10     11            Merc 280C  17.8    6    167.6  123  3.92  3.440  18.90
# ...

# %%
cars_df.isnull().sum()
# Out:
# S.No       0
# carName    0
# mpg        0
# cyl        0
# display    0
# hp         0
# drat       0
# wt         0
# qsec       3
# vs         0
# am         0
# gear       0
# carb       0
# dtype: int64

# %%
cars_df.notna().sum()
# Out:
# S.No       32
# carName    32
# mpg        32
# cyl        32
# display    32
# hp         32
# drat       32
# wt         32
# qsec       29
# vs         32
# am         32
# gear       32
# carb       32
# dtype: int64

# %%
mean_qsec = cars_df['qsec'].mean()
mean_qsec
# Out:
# 17.6748275862069

# %%
cars_df['qsec'].fillna(mean_qsec, inplace=True)
cars_df
# Out:
#     S.No              carName   mpg  cyl  display   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6    160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6    160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4    108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6    258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8    360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6    225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8    360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4    146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4    140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6    167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6    167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8    275.8  180  3.07  4.070
# 12    13           Merc 450SL  17.3    8    275.8  180  3.07  3.730
# ...

# %%
cars_df.isna().sum()
# Out:
# S.No       0
# carName    0
# mpg        0
# cyl        0
# display    0
# hp         0
# drat       0
# wt         0
# qsec       0
# vs         0
# am         0
# gear       0
# carb       0
# dtype: int64

# %%
cars_df.drop('am', axis=1,inplace=True)
cars_df
# Out:
#     S.No              carName   mpg  cyl  display   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6    160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6    160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4    108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6    258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8    360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6    225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8    360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4    146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4    140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6    167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6    167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8    275.8  180  3.07  4.070
# 12    13           Merc 450SL  17.3    8    275.8  180  3.07  3.730
# ...

# %%
cars_df.drop(range(5,7))
# Out:
#     S.No              carName   mpg  cyl  display   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6    160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6    160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4    108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6    258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8    360.0  175  3.15  3.440
# 7      8            Merc 240D  24.4    4    146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4    140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6    167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6    167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8    275.8  180  3.07  4.070
# 12    13           Merc 450SL  17.3    8    275.8  180  3.07  3.730
# 13    14          Merc 450SLC  15.2    8    275.8  180  3.07  3.780
# 14    15   Cadillac Fleetwood  10.4    8    472.0  205  2.93  5.250
# ...

# %%
cars_df.isna().sum()
# Out:
# S.No       0
# carName    0
# mpg        0
# cyl        0
# display    0
# hp         0
# drat       0
# wt         0
# qsec       0
# vs         0
# gear       0
# carb       0
# dtype: int64

# %%
car=pd.read_csv(r'C:\Users\Saurabh\Desktop\python class notes\datasets\mtcars2.csv')
car
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
car.shape
# Out:
# (32, 13)

# %%
tmp=car.dropna()

# %%
tmp.shape
# Out:
# (29, 13)

# %%
cars_df.duplicated().sum()
# Out:
# 0

# %%
cars_df.drop_duplicates()
# Out:
#     S.No              carName   mpg  cyl  display   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6    160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6    160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4    108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6    258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8    360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6    225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8    360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4    146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4    140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6    167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6    167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8    275.8  180  3.07  4.070
# 12    13           Merc 450SL  17.3    8    275.8  180  3.07  3.730
# ...

# %%
cars_df['display'].dtype
# Out:
# dtype('float64')

# %%
cars_df=cars_df['display'].astype('int')

# %%
cars_df=pd.read_csv(r'C:\Users\Saurabh\Desktop\python class notes\datasets\mtcars2.csv')
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
cars_df.iloc[:3,]
# Out:
#    S.No     Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1

# %%
cars_df.iloc[3:9,4:10]
# Out:
#     disp   hp  drat     wt   qsec  vs
# 3  258.0  110  3.08  3.215  19.44   1
# 4  360.0  175  3.15  3.440  17.02   0
# 5  225.0  105  2.76  3.460    NaN   1
# 6  360.0  245  3.21  3.570  15.84   0
# 7  146.7   62  3.69  3.190  20.00   1
# 8  140.8   95  3.92  3.150  22.90   1

# %%
cars_df.iloc[2,2]=22

# %%
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
cars_df.loc[cars_df['qsec']<18,['qsec','cyl','S.No']]
# Out:
#      qsec  cyl  S.No
# 0   16.46    6     1
# 1   17.02    6     2
# 4   17.02    8     5
# 6   15.84    8     7
# 11  17.40    8    12
# 12  17.60    8    13
# 14  17.98    8    15
# 15  17.82    8    16
# 16  17.42    8    17
# 21  16.87    8    22
# 22  17.30    8    23
# 23  15.41    8    24
# 24  17.05    8    25
# 26  16.70    4    27
# 27  16.90    4    28
# 28  14.50    8    29
# 29  15.50    6    30
# 30  14.60    8    31

# %%
cars_df.loc[(cars_df['gear']==4)& (cars_df['disp']>100),]
# Out:
#     S.No     Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0      1      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1      2  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2      3     Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1   1
# 7      8      Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8      9       Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9     10       Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10    11      Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 31    32     Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 31     4     2

# %%
cars_df.loc[1:3,]
# Out:
#    S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 1     2   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3      Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
#
#    gear  carb
# 1     4     4
# 2     4     1
# 3     3     1

# %%
cars_df['year']=2023
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
import numpy as np
cars_df['year']=np.random.randint(2010,2022,32)
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
cars_df['year']=cars_df['year'].apply(lambda x:x+3)
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
cars_df['hp']= cars_df['hp'].apply(lambda a :a+5 if a>100 else a)
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  115  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  115  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  115  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  180  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  110  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  250  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  128  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  128  3.92  3.440  18.90   1
# ...

# %%
cars_df.sort_values(by=['gear', 'year'], ascending=False, inplace=True)

# %%
cars_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 30    31        Maserati Bora  15.0    8  301.0  340  3.54  3.570  14.60   0
# 28    29       Ford Pantera L  15.8    8  351.0  269  4.22  3.170  14.50   0
# 29    30         Ferrari Dino  19.7    6  145.0  180  3.62  2.770  15.50   0
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0
# 27    28         Lotus Europa  30.4    4   95.1  118  3.77  1.513  16.90   1
# 0      1            Mazda RX4  21.0    6  160.0  115  3.90  2.620  16.46   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 10    11            Merc 280C  17.8    6  167.6  128  3.92  3.440  18.90   1
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1
# 2      3           Datsun 710  22.0    4  108.0   93  3.85  2.320  18.61   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# ...

# %%
cars_df[(cars_df['cyl']>6)& (cars_df['hp']>100)]
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 30    31        Maserati Bora  15.0    8  301.0  340  3.54  3.570  14.60   0
# 28    29       Ford Pantera L  15.8    8  351.0  269  4.22  3.170  14.50   0
# 21    22     Dodge Challenger  15.5    8  318.0  155  2.76  3.520  16.87   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  210  2.93  5.250  17.98   0
# 16    17    Chrysler Imperial  14.7    8  440.0  235  3.23  5.345  17.42   0
# 12    13           Merc 450SL  17.3    8  275.8  185  3.07  3.730  17.60   0
# 13    14          Merc 450SLC  15.2    8  275.8  185  3.07  3.780  18.00   0
# 22    23          AMC Javelin  15.2    8  304.0  155  3.15  3.435  17.30   0
# 15    16  Lincoln Continental  10.4    8  460.0  220  3.00  5.424  17.82   0
# 6      7           Duster 360  14.3    8  360.0  250  3.21  3.570  15.84   0
# 11    12           Merc 450SE  16.4    8  275.8  185  3.07  4.070  17.40   0
# ...

# %%
cars_df['cyl'].value_counts(normalize=True)
# Out:
# cyl
# 8    0.43750
# 4    0.34375
# 6    0.21875
# Name: proportion, dtype: float64

# %%
cars_df.groupby(['gear','year']).mean(numeric_only=True)
# Out:
#                 S.No        mpg       cyl    disp     hp      drat        wt  \
# gear year
# 3    2013   5.000000  18.700000  8.000000  360.00  180.0  3.150000  3.440000
#      2014  18.333333  16.866667  7.333333  325.00  180.0  3.190000  3.715000
#      2015  12.000000  16.400000  8.000000  275.80  185.0  3.070000  4.070000
#      2016   5.500000  17.850000  7.000000  309.00  182.5  3.145000  3.392500
#      2017  16.000000  10.400000  8.000000  460.00  220.0  3.000000  5.424000
#      2018  16.666667  15.900000  8.000000  285.20  175.0  3.096667  3.648333
#      2021  19.000000  18.100000  6.000000  280.05  166.0  3.465000  3.905000
#      2023  15.000000  10.400000  8.000000  472.00  210.0  2.930000  5.250000
#      2024  22.000000  15.500000  8.000000  318.00  155.0  2.760000  3.520000
# 4    2013  21.000000  20.300000  5.000000  144.30  121.0  4.015000  3.110000
#      2014  18.000000  32.400000  4.000000   78.70   66.0  4.080000  2.200000
# ...

# %%
cars_df.groupby('gear').agg(mean_hp=('hp','mean'),sum_hp=('hp','sum'))
# Out:
#          mean_hp  sum_hp
# gear
# 3     180.800000    2712
# 4      91.583333    1099
# 5     199.600000     998

# %%
def setcolor(x):
    if x==3:
        return "blue"
    elif x==4:
        return "red"
    elif x==5:
        return "green"
    else:
        return "black"

# %%
cars_df['colour']=cars_df['gear'].apply(setcolor)

# %%
cars_df['colour']
# Out:
# 30    green
# 28    green
# 29    green
# 26    green
# 27    green
# 0       red
# 7       red
# 10      red
# 18      red
# 2       red
# 8       red
# 25      red
# 1       red
# 19      red
# 17      red
# 9       red
# 31      red
# 21     blue
# 14     blue
# 16     blue
# 20     blue
# 12     blue
# 13     blue
# 22     blue
# 15     blue
# 3      blue
# 6      blue
# 11     blue
# 5      blue
# 23     blue
# 24     blue
# 4      blue
# Name: colour, dtype: object
